# %% [markdown]
# # Investigate a Dataset

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this report, the data focus on the population of the country, income per person and literacy of the youth (15-24).
# * **population**- indicates the population of the countries
# * **income**-indicates the GDP per person adjusted for differences in purchasing power(in international dollars, fixed 2011       prices, PPP based on 2011 ICP)
# * **expenditure**- indicates average general government expenditure per student in the given level of expenditure,
#   expressed as percentage of GDP per capita.
# * **youth_rate**-indicates youth literacy rate between age 15-24 who can, with understanding read and write a short, simple       statement on their everyday life
# * **male_rate**-indicates male youth literacy percent rate between age 15-24 with understanding read and write
# * **female_rate**-indicates female youth literacy percent rate between age 15-24 with understanding read and     write
# * **male_mean**-indicates the average number of years of shool attended by men(primary, secondary,tertiary education)
# * **female_mean**-indicates the average number of years of school attended by women(primary,secodary,teritiary education)
#
#
# The given data is taken from [**GAPMINDER**](https://www.gapminder.org/data/)

# %%
#importing packages
import pandas as pa
import numpy as np
import matplotlib.pyplot as mat
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# # DATA WRANGLING
#
# ### General Properties
#
# ##### 1. Gathering the data- The first step is to choose the data and gather all the data

# %%
#loading the data
population = pa.read_csv("population_total.csv")
income=pa.read_csv("income_per_person.csv")
youth_rate=pa.read_csv("rate_youth_total_percent_ages_15_24.csv") 
male_rate=pa.read_csv("rate_youth_male_ages_15_24.csv")
female_rate=pa.read_csv("rate_youth_female_ages_15_24.csv")
male_mean=pa.read_csv("mean_years_in_school_men_15_24.csv")
female_mean=pa.read_csv("mean_years_in_school_women_15_24.csv")
expenditure=pa.read_csv("expenditure_per_student.csv")

# %% [markdown]
#  >Printing the first 5 rows of the data and checking if there are any missing values in the data

# %%
#printing the first 5 rows of the data to observe

population[:5]
# Out:
#        country     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   400000   402000   404000   405000   407000   409000   411000
# 2      Algeria  2500000  2510000  2520000  2530000  2540000  2550000  2560000
# 3      Andorra     2650     2650     2650     2650     2650     2650     2650
# 4       Angola  1570000  1570000  1570000  1570000  1570000  1570000  1570000
#
#       1807     1808  ...       2091       2092       2093       2094  \
# 0  3280000  3280000  ...   76600000   76400000   76300000   76100000
# 1   413000   414000  ...    1330000    1300000    1270000    1250000
# 2  2560000  2570000  ...   70400000   70500000   70500000   70600000
# 3     2650     2650  ...      63000      62900      62900      62800
# 4  1570000  1570000  ...  168000000  170000000  172000000  175000000
#
#         2095       2096       2097       2098       2099       2100
# ...

# %%
income[:5]
# Out:
#        country  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0  Afghanistan   603   603   603   603   603   603   603   603   603  ...
# 1      Albania   667   667   667   667   667   668   668   668   668  ...
# 2      Algeria   715   716   717   718   719   720   721   722   723  ...
# 3      Andorra  1200  1200  1200  1200  1210  1210  1210  1210  1220  ...
# 4       Angola   618   620   623   626   628   631   634   637   640  ...
#
#     2031   2032   2033   2034   2035   2036   2037   2038   2039   2040
# 0   2550   2600   2660   2710   2770   2820   2880   2940   3000   3060
# 1  19400  19800  20200  20600  21000  21500  21900  22300  22800  23300
# 2  14300  14600  14900  15200  15500  15800  16100  16500  16800  17100
# 3  73600  75100  76700  78300  79900  81500  83100  84800  86500  88300
# 4   6110   6230   6350   6480   6610   6750   6880   7020   7170   7310
#
# [5 rows x 242 columns]

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Columns: 242 entries, country to 2040
# dtypes: int64(241), object(1)
# memory usage: 365.0+ KB

# %%
youth_rate[:5]
# Out:
#        country  1975  1976  1977  1978   1979   1980  1981  1982  1983  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN  0.301    NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 3       Angola   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 4    Argentina   NaN   NaN   NaN   NaN    NaN  0.969   NaN   NaN   NaN  ...
#
#     2002  2003  2004  2005   2006  2007   2008  2009  2010   2011
# 0    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN    NaN
# 1    NaN   NaN   NaN   NaN    NaN   NaN  0.988   NaN   NaN  0.988
# 2  0.901   NaN   NaN   NaN  0.918   NaN    NaN   NaN   NaN    NaN
# 3    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN  0.730
# 4    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN  0.992
#
# [5 rows x 38 columns]

# %%
#to check the missing values
youth_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 38 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  149 non-null    object
#  1   1975     6 non-null      float64
#  2   1976     7 non-null      float64
#  3   1977     1 non-null      float64
#  4   1978     2 non-null      float64
#  5   1979     7 non-null      float64
#  6   1980     17 non-null     float64
#  7   1981     17 non-null     float64
#  8   1982     7 non-null      float64
#  9   1983     2 non-null      float64
#  10  1984     4 non-null      float64
#  11  1985     6 non-null      float64
#  12  1986     4 non-null      float64
#  13  1987     3 non-null      float64
#  14  1988     4 non-null      float64
#  15  1989     10 non-null     float64
#  16  1990     15 non-null     float64
#  17  1991     22 non-null     float64
#  18  1992     9 non-null      float64
#  19  1993     4 non-null      float64
# ...

# %%
male_rate[:5]
# Out:
#        country  1975  1976  1977  1978   1979   1980  1981  1982  1983  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN  0.458    NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 3       Angola   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 4    Argentina   NaN   NaN   NaN   NaN    NaN  0.965   NaN   NaN   NaN  ...
#
#     2002  2003  2004  2005   2006  2007   2008  2009  2010   2011
# 0    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN    NaN
# 1    NaN   NaN   NaN   NaN    NaN   NaN  0.985   NaN   NaN  0.987
# 2  0.941   NaN   NaN   NaN  0.944   NaN    NaN   NaN   NaN    NaN
# 3    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN  0.801
# 4    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN  0.990
#
# [5 rows x 38 columns]

# %%
male_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 38 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  149 non-null    object
#  1   1975     6 non-null      float64
#  2   1976     7 non-null      float64
#  3   1977     1 non-null      float64
#  4   1978     2 non-null      float64
#  5   1979     7 non-null      float64
#  6   1980     17 non-null     float64
#  7   1981     16 non-null     float64
#  8   1982     7 non-null      float64
#  9   1983     2 non-null      float64
#  10  1984     4 non-null      float64
#  11  1985     6 non-null      float64
#  12  1986     4 non-null      float64
#  13  1987     3 non-null      float64
#  14  1988     4 non-null      float64
#  15  1989     10 non-null     float64
#  16  1990     15 non-null     float64
#  17  1991     21 non-null     float64
#  18  1992     9 non-null      float64
#  19  1993     4 non-null      float64
# ...

# %%
female_rate[:5]
# Out:
#        country  1975  1976  1977  1978   1979   1980  1981  1982  1983  ...  \
# 0  Afghanistan   NaN   NaN   NaN   NaN  0.111    NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 2      Algeria   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 3       Angola   NaN   NaN   NaN   NaN    NaN    NaN   NaN   NaN   NaN  ...
# 4    Argentina   NaN   NaN   NaN   NaN    NaN  0.973   NaN   NaN   NaN  ...
#
#     2002  2003  2004  2005   2006  2007   2008  2009  2010   2011
# 0    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN    NaN
# 1    NaN   NaN   NaN   NaN    NaN   NaN  0.991   NaN   NaN  0.989
# 2  0.861   NaN   NaN   NaN  0.891   NaN    NaN   NaN   NaN    NaN
# 3    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN  0.661
# 4    NaN   NaN   NaN   NaN    NaN   NaN    NaN   NaN   NaN  0.994
#
# [5 rows x 38 columns]

# %%
female_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 38 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  149 non-null    object
#  1   1975     6 non-null      float64
#  2   1976     7 non-null      float64
#  3   1977     1 non-null      float64
#  4   1978     2 non-null      float64
#  5   1979     7 non-null      float64
#  6   1980     17 non-null     float64
#  7   1981     16 non-null     float64
#  8   1982     7 non-null      float64
#  9   1983     2 non-null      float64
#  10  1984     4 non-null      float64
#  11  1985     6 non-null      float64
#  12  1986     4 non-null      float64
#  13  1987     3 non-null      float64
#  14  1988     4 non-null      float64
#  15  1989     10 non-null     float64
#  16  1990     15 non-null     float64
#  17  1991     21 non-null     float64
#  18  1992     9 non-null      float64
#  19  1993     4 non-null      float64
# ...

# %% [markdown]
# > The information of the youth rate, the male rate and the female rate is available till the year 2011

# %%
male_mean[:5]
# Out:
#        country  1970  1971  1972  1973  1974  1975   1976   1977   1978  ...  \
# 0  Afghanistan  1.82  1.87  1.92  1.97  2.02  2.07   2.12   2.17   2.23  ...
# 1      Albania  5.47  5.58  5.69  5.80  5.91  6.02   6.13   6.24   6.36  ...
# 2      Algeria  2.77  2.86  2.95  3.04  3.14  3.25   3.35   3.46   3.58  ...
# 3      Andorra  9.16  9.30  9.44  9.58  9.72  9.86  10.00  10.10  10.30  ...
# 4       Angola  2.25  2.31  2.36  2.42  2.48  2.54   2.60   2.67   2.73  ...
#
#     2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0   4.33   4.43   4.53   4.63   4.73   4.84   4.94   5.05   5.16   5.27
# 1   9.89  10.00  10.20  10.30  10.40  10.60  10.70  10.90  11.00  11.20
# 2   8.13   8.28   8.42   8.57   8.71   8.85   8.99   9.14   9.28   9.42
# 3  13.90  14.10  14.20  14.30  14.40  14.50  14.60  14.70  14.80  14.90
# 4   5.10   5.21   5.32   5.43   5.55   5.66   5.78   5.90   6.02   6.14
#
# [5 rows x 47 columns]

# %%
male_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  187 non-null    object
#  1   1970     187 non-null    float64
#  2   1971     187 non-null    float64
#  3   1972     187 non-null    float64
#  4   1973     187 non-null    float64
#  5   1974     187 non-null    float64
#  6   1975     187 non-null    float64
#  7   1976     187 non-null    float64
#  8   1977     187 non-null    float64
#  9   1978     187 non-null    float64
#  10  1979     187 non-null    float64
#  11  1980     187 non-null    float64
#  12  1981     187 non-null    float64
#  13  1982     187 non-null    float64
#  14  1983     187 non-null    float64
#  15  1984     187 non-null    float64
#  16  1985     187 non-null    float64
#  17  1986     187 non-null    float64
#  18  1987     187 non-null    float64
#  19  1988     187 non-null    float64
# ...

# %%
female_mean[:5]
# Out:
#        country  1970  1971  1972   1973   1974   1975   1976   1977   1978  \
# 0  Afghanistan  0.48  0.50  0.51   0.53   0.55   0.57   0.59   0.61   0.63
# 1      Albania  4.99  5.11  5.24   5.36   5.49   5.62   5.75   5.88   6.02
# 2      Algeria  3.61  3.71  3.82   3.93   4.04   4.15   4.27   4.39   4.51
# 3      Andorra  9.50  9.67  9.84  10.00  10.20  10.30  10.50  10.70  10.80
# 4       Angola  1.64  1.69  1.74   1.80   1.85   1.91   1.97   2.03   2.10
#
#    ...   2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0  ...   1.60   1.66   1.71   1.77   1.82   1.88   1.94   2.00   2.07   2.13
# 1  ...  10.20  10.40  10.50  10.70  10.90  11.00  11.20  11.40  11.50  11.70
# 2  ...   8.78   8.94   9.11   9.28   9.45   9.62   9.78   9.95  10.10  10.30
# 3  ...  15.00  15.10  15.30  15.40  15.50  15.60  15.70  15.80  16.00  16.10
# 4  ...   4.77   4.90   5.03   5.16   5.30   5.43   5.57   5.71   5.85   6.00
#
# [5 rows x 47 columns]

# %%
female_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 47 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  187 non-null    object
#  1   1970     187 non-null    float64
#  2   1971     187 non-null    float64
#  3   1972     187 non-null    float64
#  4   1973     187 non-null    float64
#  5   1974     187 non-null    float64
#  6   1975     187 non-null    float64
#  7   1976     187 non-null    float64
#  8   1977     187 non-null    float64
#  9   1978     187 non-null    float64
#  10  1979     187 non-null    float64
#  11  1980     187 non-null    float64
#  12  1981     187 non-null    float64
#  13  1982     187 non-null    float64
#  14  1983     187 non-null    float64
#  15  1984     187 non-null    float64
#  16  1985     187 non-null    float64
#  17  1986     187 non-null    float64
#  18  1987     187 non-null    float64
#  19  1988     187 non-null    float64
# ...

# %% [markdown]
# > The information of the male mean and the female mean is available till the year 2015

# %%
expenditure[:5]
# Out:
#                country  1970  1971  1972  1973  1974  1975  1976  1977  1978  \
# 0          Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1              Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2              Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3               Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  Antigua and Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...   2009  2010   2011  2012   2013   2014   2015   2016   2017   2018
# 0  ...    NaN   NaN  0.961   NaN    NaN  0.582    NaN    NaN    NaN    NaN
# 1  ...    NaN   NaN    NaN   NaN  0.129    NaN  0.129  0.146  0.138    NaN
# 2  ...    NaN   NaN    NaN   NaN  0.168  0.290  0.277  0.271  0.237  0.223
# 3  ...    NaN   NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4  ...  0.155   NaN    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 50 columns]

# %%
expenditure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 50 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  160 non-null    object
#  1   1970     1 non-null      float64
#  2   1971     0 non-null      float64
#  3   1972     0 non-null      float64
#  4   1973     0 non-null      float64
#  5   1974     0 non-null      float64
#  6   1975     0 non-null      float64
#  7   1976     0 non-null      float64
#  8   1977     0 non-null      float64
#  9   1978     0 non-null      float64
#  10  1979     0 non-null      float64
#  11  1980     0 non-null      float64
#  12  1981     0 non-null      float64
#  13  1982     0 non-null      float64
#  14  1983     0 non-null      float64
#  15  1984     1 non-null      float64
#  16  1985     1 non-null      float64
#  17  1986     1 non-null      float64
#  18  1987     0 non-null      float64
#  19  1988     1 non-null      float64
# ...

# %% [markdown]
# > In every indicator there are some missing values.
# There are some indicators which are not updated recently

# %% [markdown]
# #### 2. Cleaning the data-
# There are some indicators which are not updated recently. The percentage of the youth rate, the male rate and the female rate
# of the age 15-24 is available till the year 2011. The male mean and the female mean of the age 15-24 is available till the year 2015.The data on expenditure spent by Government on per student is available till the year 2018.
# I'm choosing the year 2011 as a common year in all the indicators and changing their column names then merging the multiple dataframe in a single dataframe.

# %%
#selection the year 2011 and changing the column name
popn=population[['country','2011']]
popn=popn.rename(columns={'2011':'Population'})

inc=income[['country','2011']]
inc=inc.rename(columns={'2011':'GDP'})

rate=youth_rate[['country','2011']]
rate=rate.rename(columns={'2011':'Youth_Rate'})

male=male_rate[['country','2011']]
male=male.rename(columns={'2011':'Male_Rate'})

female=female_rate[['country','2011']]
female=female.rename(columns={'2011':'Female_Rate'})

m_mean=male_mean[['country','2011']]
m_mean=m_mean.rename(columns={'2011':'Male_Mean'})

f_mean=female_mean[['country','2011']]
f_mean=f_mean.rename(columns={'2011':'Female_Mean'})

expend=expenditure[['country','2011']]
expend=expend.rename(columns={'2011':'Expenditure'})

# %%
#merging the data
data=(popn.merge(inc,how='outer').merge(rate,how='outer').merge(male,how='outer').merge(female,how='outer').merge(m_mean,how='outer').merge(f_mean,how='outer').merge(expend,how='outer'))

# %% [markdown]
# > As it is difficult to find the missing values and analysis the missing values of every indicator in the year 2011, I'm filtering the data

# %%
#Filtering the rows which has missing values
data=data.dropna()

# %%
#the final data
data
# Out:
#                       country  Population      GDP  Youth_Rate  Male_Rate  \
# 6                   Argentina    41300000  19800.0       0.992      0.990
# 7                     Armenia     2880000   7020.0       0.998      0.997
# 13                 Bangladesh   149000000   2650.0       0.787      0.771
# 25                   Bulgaria     7380000  15700.0       0.979      0.981
# 31                 Cape Verde      499000   6100.0       0.984      0.977
# 32   Central African Republic     4420000   1020.0       0.656      0.723
# 33                       Chad    12400000   1850.0       0.479      0.536
# 36                   Colombia    45700000  11700.0       0.982      0.978
# 37                    Comoros      707000   2470.0       0.860      0.861
# 40                 Costa Rica     4630000  13300.0       0.983      0.979
# 41              Cote d'Ivoire    21000000   2500.0       0.675      0.723
# 42                    Croatia     4310000  20800.0       0.997      0.996
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# > The data is divided into two parts
# 1. LOW INCOME V/S HIGH INCOME
# 2. LOW YOUTH RATE V/S HIGH YOUTH RATE
#
# The purpose of dividing the data is two parts is to see the relation between GDP per capita and the education of the youth.

# %% [markdown]
# **1. LOW INCOME V/S HIGH INCOME**

# %% [markdown]
# In this data, we will observe that if there is relation between the GDP per capita and the expenditure the Government per student. Even after the Government Expenditure, what is the youth rate, male rate and the female rate of the age 15-24. Is there any gender baised or not. Comparison between mean years attended school by male and female.

# %%
#Dividing the countries in two category
i_median=data['GDP'].median()
low_income=data.query('GDP <@i_median') #the country with low income in the dataset
high_income=data.query('GDP >=@i_median') #the country with high income in the dataset

# %%
i_median
# Out:
# 8280.0

# %%
low_income
# Out:
#                       country  Population     GDP  Youth_Rate  Male_Rate  \
# 7                     Armenia     2880000  7020.0       0.998      0.997
# 13                 Bangladesh   149000000  2650.0       0.787      0.771
# 31                 Cape Verde      499000  6100.0       0.984      0.977
# 32   Central African Republic     4420000  1020.0       0.656      0.723
# 33                       Chad    12400000  1850.0       0.479      0.536
# 37                    Comoros      707000  2470.0       0.860      0.861
# 41              Cote d'Ivoire    21000000  2500.0       0.675      0.723
# 61                     Gambia     1850000  1440.0       0.681      0.726
# 62                    Georgia     4080000  7550.0       0.998      0.998
# 67                  Guatemala    14900000  6850.0       0.874      0.893
# 83                    Jamaica     2830000  8110.0       0.956      0.929
# 104                      Mali    15500000  1880.0       0.469      0.560
# ...

# %% [markdown]
# ### Question 1- Is literacy rate of the youth age 15-24 related to GDP per capita?

# %%
low_income.reset_index().plot(x='country',y=['Youth_Rate','Male_Rate', 'Female_Rate'], kind='bar', figsize=(20,10))

# %% [markdown]
# > 1. According to the graph there are 19 countries lies in the category low GDP per capita and the most the countries have high literacy rate of the overall youth and the male and female except of the countries Chad and Mali which lies in the range below 50%.
# 2. There are some countries have equal percentile of literacy rate and there are some countries which show gender bias.

# %% [markdown]
# ### QUESTION 2- IS AVERAGE NUMBER OF YEARS OF SCHOOL ATTENDED BY THE YOUTH IS RELATED BY GDP PER CAPITA AND IS THERE ANY GENDER BIAS?

# %%
low_income.reset_index().plot(x='country', y=['Male_Mean','Female_Mean'], kind='bar', figsize=(20,10))

# %% [markdown]
# > 1. There are some countries which show that male have attended more number of years of school than female.
# 2. 6 out of 19 countries have attended school more than 8 number of years.

# %% [markdown]
# ### QUESTION 3- DOES EXPENDITURE ON EDUCATION PER STUDENT AFFECTED YOUTH LITERACY RATE?

# %%
low_income.plot(x='country', y='Expenditure', kind='bar',figsize=(10,10));

# %% [markdown]
# > 1. Cote d'lvoire spends about 340% on education per student GDP per capita and still has very less literacy youth rate and the the average number of school attend by the people is very less
# 2. Moldova has 100% literacy youth rate and it spends on education per student about 35% GDP per capita and it has average number of school attended by the youth is 11-12 years
# 3. Armenia has average of 99% literacy youth rate. The country spends on education per student about 0.72% GDP per capita and it has average number of school attended by the youth is 11 years

# %%
high_income
# Out:
#         country  Population      GDP  Youth_Rate  Male_Rate  Female_Rate  \
# 6     Argentina    41300000  19800.0       0.992      0.990        0.994
# 25     Bulgaria     7380000  15700.0       0.979      0.981        0.977
# 36     Colombia    45700000  11700.0       0.982      0.978        0.987
# 40   Costa Rica     4630000  13300.0       0.983      0.979        0.987
# 42      Croatia     4310000  20800.0       0.997      0.996        0.997
# 44       Cyprus     1120000  33200.0       0.998      0.998        0.998
# 55      Estonia     1330000  24500.0       0.998      0.998        0.998
# 74      Hungary     9900000  22800.0       0.989      0.988        0.990
# 82        Italy    59600000  36300.0       0.999      0.999        0.999
# 92       Latvia     2090000  19800.0       0.997      0.997        0.997
# 98    Lithuania     3080000  22900.0       0.998      0.998        0.998
# 108   Mauritius     1250000  16600.0       0.968      0.958        0.978
# ...

# %% [markdown]
# ### QUESTION 4- WHAT IS LITERACY YOUTH OF HIGH INCOME PER GDP?

# %%
high_income.reset_index().plot(x='country',y=['Youth_Rate','Male_Rate', 'Female_Rate'], kind='bar', figsize=(20,10))

# %% [markdown]
# > There are 20 countries which have higher GDP per capita. According to the graph all the countries have high literacy youth rate. There is no gender bias.

# %% [markdown]
# ### QUESTION 5- WHAT IS AVERAGE NUMBER OF YEARS OF SCHOOL ATTENDED BY YOUTH AND IS THERE ANY GENDER BIAS IN HIGH INCOME PER CAPITA?

# %%
high_income.reset_index().plot(x='country', y=['Male_Mean','Female_Mean'], kind='bar', figsize=(20,10))

# %% [markdown]
# > According to the graph all the countries has attended the average number of years of school atleast for 10 years. Almost of all the countries have higher average number of years of school by Female than the male.

# %% [markdown]
# ### QUESTION 6- COMPARISON BETWEEN COUNTRIES WHICH SPENDS MORE ON EDUCATION WHICH MIGHT BE THE RESULT ON HIGH LITERACY YOUTH RATE IN HIGH INCOME PER CAPITA?

# %%
high_income.plot(x='country',y='Expenditure',kind='bar')

# %% [markdown]
# > According to the graph the Government expenditure per student is less 40% GDP per capita and Mongolia spends least on eduction per student.

# %% [markdown]
# **2-LOW YOUTH RATE V/S HIGH YOUTH RATE-**

# %% [markdown]
# In this data we will observe that low literacy youth rate and high literacy youth rate. We will observe that how much Government spend on the education per student, what is the GDP of the country and how many average number of years of school attend by the youth of age 15-24.

# %%
#diving the data by the youth literacy rate
youth_median=data['Youth_Rate'].median()
low_rate=data.query('Youth_Rate <@youth_median')
high_rate=data.query('Youth_Rate >=@youth_median')

# %%
youth_median
# Out:
# 0.983

# %%
low_rate
# Out:
#                       country  Population      GDP  Youth_Rate  Male_Rate  \
# 13                 Bangladesh   149000000   2650.0       0.787      0.771
# 25                   Bulgaria     7380000  15700.0       0.979      0.981
# 32   Central African Republic     4420000   1020.0       0.656      0.723
# 33                       Chad    12400000   1850.0       0.479      0.536
# 36                   Colombia    45700000  11700.0       0.982      0.978
# 37                    Comoros      707000   2470.0       0.860      0.861
# 41              Cote d'Ivoire    21000000   2500.0       0.675      0.723
# 61                     Gambia     1850000   1440.0       0.681      0.726
# 67                  Guatemala    14900000   6850.0       0.874      0.893
# 83                    Jamaica     2830000   8110.0       0.956      0.929
# 104                      Mali    15500000   1880.0       0.469      0.560
# 107                Mauritania     3600000   3480.0       0.690      0.716
# ...

# %% [markdown]
# ### QUESTION 7- PROBABLY EXPENDITURE ON EDUCATION PER STUDENT AFFECTS THE LOW LITERACY YOUTH RATE?

# %%
low_rate.plot(x='Expenditure',y='Youth_Rate',kind='scatter')

# %% [markdown]
# > It shows negative relationship between literacy youth rate and the expenditure

# %% [markdown]
# ### QUESTION 8- THE GDP PER CAPITA DEPENDS ON THE LITERACY YOUTH RATE?

# %%
low_rate.plot(x='GDP', y='Youth_Rate',kind='scatter')

# %% [markdown]
# > The range from USD 2500- USD 5000 shows the positive relationship between GDP per capita and the youth literacy rate.
# After USD 5000 it shows the constant relationship between GDP per capita and the Youth literacy rate.

# %% [markdown]
# ### QUESTION 9- THE AVERAGE NUMBER OF YEARS OF SCHOOL ATTENDED BY THE YOUTH HAS AFFECTED THE LOW LITERACY RATE?

# %%
low_rate.reset_index().plot(x='country', y=['Male_Mean','Female_Mean'], kind='bar', figsize=(20,10))

# %% [markdown]
# > Most of the countries have below 8 average number of years of school attended by the male and female.

# %%
high_rate
# Out:
#         country  Population      GDP  Youth_Rate  Male_Rate  Female_Rate  \
# 6     Argentina    41300000  19800.0       0.992      0.990        0.994
# 7       Armenia     2880000   7020.0       0.998      0.997        0.998
# 31   Cape Verde      499000   6100.0       0.984      0.977        0.993
# 40   Costa Rica     4630000  13300.0       0.983      0.979        0.987
# 42      Croatia     4310000  20800.0       0.997      0.996        0.997
# 44       Cyprus     1120000  33200.0       0.998      0.998        0.998
# 55      Estonia     1330000  24500.0       0.998      0.998        0.998
# 62      Georgia     4080000   7550.0       0.998      0.998        0.998
# 74      Hungary     9900000  22800.0       0.989      0.988        0.990
# 82        Italy    59600000  36300.0       0.999      0.999        0.999
# 92       Latvia     2090000  19800.0       0.997      0.997        0.997
# 98    Lithuania     3080000  22900.0       0.998      0.998        0.998
# ...

# %% [markdown]
# ### QUESTION 10- IF THE COUNTRY SPENDS MORE ON EDUCATION THERE MIGHT BE HIGH LITERACY YOUTH RATE?

# %%
high_rate.plot(x='Expenditure',y='Youth_Rate',kind='scatter')

# %% [markdown]
# > This shows that it has no relationship between Expenditure on education per student and the Youth literacy rate.

# %% [markdown]
# ### QUESTION 11- THERE MIGHT BE POSITIVE CORRELATION BETWEEN GPD PER CAPITA AND LITERACY YOUTH RATE?

# %%
high_rate.plot(x='GDP',y='Youth_Rate',kind='scatter')

# %% [markdown]
# > This shows that it has no relation between GDP per capita and Youth literacy rate

# %% [markdown]
# ### QUESTION 12- HIGHER NUMBER OF AVERAGE NUMBER OF YEARS ATTENDED BY SCHOOL MAYBE THE REASON FOR HIGH LITERACY YOUTH RATE?

# %%
high_rate.reset_index().plot(x='country', y=['Male_Mean','Female_Mean'], kind='bar', figsize=(20,10))

# %% [markdown]
# > Most of the countries have atleast attended 9 average years of school by the youth.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# 1. LOW INCOME- Chad and Mali have low literacy youth rate and there is gender bias in the education. The average number of years of school is attended by male is more than average number of years of school is attended by female. They spend almost 200% on education per student of GDP per capita.
#
# 2. Cote d'Ivoire spends almost 340% on education per student of GDP per capita. The literacy youth rate is almost 67% which is less compare to the most of the countries. The GDP is USD 2500 per capita.
#
# 3. According to the data, the low income per capita spends on more education per student and their literacy youth rate is also less. In the second data in which low literacy youth rate, shows that there is negative relaionship between Expenditure on education per student and Youth literacy rate.
#
# 4. In the data High income per capita, shows that the literacy youth rate is almost 98%. The average number of school attended by youth is atleast for 10 years. The countries spend on education per student is less than 40% which is very less comparitive than low income per capita.
#
# 5. In the second data high literacy youth rate, shows that there is no relationship between expenditure on education per student and the youth literacy youth rate. This shows that expenditure on education is not related to high literacy youth rate there may be different factors.
